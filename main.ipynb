# %% [markdown]
# ## Initialize Project

# %%
# Pull lastest code from Github
# !git clone https://github.com/DanRArcega/ML_Garbage_Classification

# %%
# Install libraries
# !pip install mlcroissant -q

# %%
## Download data
# !cd ML_Garbage_Classification/code && python download_data.py

# %% [markdown]
# ## Run classification

# %%
# !cd ML_Garbage_Classification/code && python main.py
